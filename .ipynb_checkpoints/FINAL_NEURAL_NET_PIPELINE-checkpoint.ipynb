# %% [markdown]
# ### FINAL PROJECT CODE
#
# Our final Project consists of a neural network for classifying songs, Another neural network for analysing user schedule to see if the next song on the playlist should degrease or increase energy. 1 of 2 RNNs are used to analyse song and pick a song with the appropriate song. One RNN is trained to boost song energy and the other to drop energy. The choice of RNN to use is made by the second neural nertwork in the pipeline

# %%
# imports 
import pandas as pd
import os
import random
from sklearn import preprocessing as preproc
import numpy as np
import tensorflow as tf

# %% [markdown]
# #### Step 1: Load Users Playlist Data

# %%
DATA_DIR = "DataSets"

user_playlist_file = "TestSongDataSetLess.xlsx"
user_playlist_file = os.path.join(DATA_DIR, user_playlist_file)
user_df = pd.read_excel(user_playlist_file)
print("---------------------------   USERS RAW DATA   ---------------------------")
key_no_norm = user_df["key"]
user_df.head()
# Out:
# ---------------------------   USERS RAW DATA   ---------------------------
#                                             name            artist  key  \
# 0                                      Losing It            FISHER    2
# 1  Midnight Hour with Boys Noize & Ty Dolla $ign          Skrillex    0
# 2                                         Clouds        Zonderling    1
# 3               Hypnagogic (I Can't Wait) [edit]  Love Regenerator    9
# 4                         Your Mind - Radio Edit        Adam Beyer   11
#
#    liveness  instrumentalness  loudness  mode  speechiness    tempo  valence  \
# 0    0.0974          0.700000    -5.844     1       0.0576  125.000   0.6410
# 1    0.1990          0.000392    -4.202     1       0.0685  125.978   0.3290
# 2    0.7780          0.840000    -5.362     1       0.0957  125.953   0.0813
# 3    0.1080          0.766000    -3.852     0       0.0458  139.982   0.2500
# 4    0.2150          0.165000    -7.946     0       0.0565  126.032   0.1110
#
#    danceability  energy  acousticness
# 0         0.760   0.964       0.00182
# 1         0.795   0.899       0.00235
# 2         0.681   0.926       0.04950
# 3         0.422   0.957       0.00288
# 4         0.660   0.857       0.00262

# %%
## Some of The Data isn't normalized so gonna make a pre proc function for the playlist data
# so it is ready to be run through through the categorization neural network

def preproc_userdata(df):
    for col in df.columns:
        if col in ["key", "loudness", "tempo"]:
            df[col] = preproc.scale(df[col].values)

    df.dropna(inplace=True)
    data = []
    for row in df.values:
        data.append(np.array(row[2:], dtype=np.float64))
        
    X_data = []
    
    for X in data:
        X_data.append(X)

    
        
    return np.array(X_data)

# %%
X = preproc_userdata(user_df)

# %%
# X data is now an np array that can be fed into aout neural network model
X
# Out:
# array([[-8.93641985e-01,  9.74000000e-02,  7.00000000e-01, ...,
#          7.60000000e-01,  9.64000000e-01,  1.82000000e-03],
#        [-1.44792450e+00,  1.99000000e-01,  3.92000000e-04, ...,
#          7.95000000e-01,  8.99000000e-01,  2.35000000e-03],
#        [-1.17078324e+00,  7.78000000e-01,  8.40000000e-01, ...,
#          6.81000000e-01,  9.26000000e-01,  4.95000000e-02],
#        ...,
#        [-8.93641985e-01,  1.11000000e-01,  8.57000000e-01, ...,
#          2.70000000e-01,  7.51000000e-02,  9.92000000e-01],
#        [-1.17078324e+00,  1.09000000e-01,  9.28000000e-01, ...,
#          2.84000000e-01,  3.08000000e-02,  9.89000000e-01],
#        [-1.44792450e+00,  1.15000000e-01,  8.46000000e-01, ...,
#          2.60000000e-01,  1.66000000e-02,  9.80000000e-01]])

# %% [markdown]
# #### Step 2: Use NN to categorize Data

# %%
BeastMode = []
Studying = []
BeachSongs = []
Relaxing = []

MODEL_DIR = "Models"

# Load Model
file_name = os.path.join(MODEL_DIR,"simp_neural_net_2l_60n")
Song_categorizer_model = tf.keras.models.load_model(file_name)

# Make Predctions
predictions = Song_categorizer_model.predict(X)

predicted_category = [0] * len(predictions)
# Arg Max The predictions
for i,prediction in enumerate(predictions):
    predicted_category[i] = np.argmax(prediction)
    

for i,prediction in enumerate(predicted_category):
    song_dic = user_df.iloc[i].to_dict()
    song_dic["key_no_norm"] = key_no_norm.iloc[i]
    if prediction == 0:
        BeastMode.append(song_dic)
    elif prediction == 1:
        Studying.append(song_dic)
    elif prediction == 2:
        BeachSongs.append(song_dic)
    elif prediction ==3:
        Relaxing.append(song_dic)

# %%
#Remove later
print(len(BeastMode),
len(Relaxing),
len(Studying),
len(BeachSongs))
# Out:
# 807 1088 936 1169

# %%
# Checking out some of the song selections
BeastMode[777]
# Out:
# {'name': 'Under the Sun',
#  'artist': 'Miskeyz',
#  'key': -0.33935946992199967,
#  'liveness': 0.228,
#  'instrumentalness': 0.771,
#  'loudness': 0.7966370049281668,
#  'mode': 0,
#  'speechiness': 0.0336,
#  'tempo': 0.19812018382713947,
#  'valence': 0.0947,
#  'danceability': 0.764,
#  'energy': 0.736,
#  'acousticness': 0.00135,
#  'key_no_norm': 4}

# %% [markdown]
# ##### Imput Schedule of The USER IN BOTTOM CELL

# %%
# for Schedule is a list of tuples. The tuples contain activity and duration
#### Key:
# BeastMode = 1
# Studying = 2
# BeachSongs = 3
# Relaxing = 4


schedule1 = [{"activity":1, "duration":2},{"activity":2, "duration":1},{"activity":3, "duration":2}]  #BeastMode for 2 hrs, Studying for 1 hours, Relaxing for 3 hours

# %% [markdown]
# #### Step 4: Load RRN models and Energy Picker Model

# %%
MODEL_DIR = "models"
energy_picker_model = "NN_Energy_change_picker"
rnn_boost_model = "RNN_boost1"
rnn_drop_model = "RNN_drop1"

file_name = os.path.join(MODEL_DIR, energy_picker_model)
energy_changer_NN = tf.keras.models.load_model(file_name)

file_name = os.path.join(MODEL_DIR, rnn_boost_model)
rnn_boost = tf.keras.models.load_model(file_name)

file_name = os.path.join(MODEL_DIR, rnn_drop_model)
rnn_drop = tf.keras.models.load_model(file_name)

# %% [markdown]
# #### Step 5: Make Playlist with categorized song data

# %%
## HELPER FUNCTIONS

# Function to change song dictionary to a form the RNN is expecting
def song_features(song1, song2):
    song1_key = song1['key_no_norm']
    song1_mode = [song1["mode"]]
    song1_tempo = [song1["tempo"]]
    
    song2_key = song2['key_no_norm']
    song2_mode = [song2["mode"]]
    song2_tempo = [song2["tempo"]]
    
    # Change key into hot key
    zeros = [0] * 12
    song1_keylist = zeros
    song2_keylist = zeros
    song1_keylist[song1_key - 1] = 1
    song2_keylist[song2_key - 1] = 1
    
    # Combine Data
    data1 = song1_mode + song1_tempo + song1_keylist
    data2 = song2_mode + song2_tempo + song2_keylist 
    data =  [ data1, data2 ]
    
    return np.array([data, data])


# Function to get features needed for the time_left neural network
def time_left_feat(activity1, activity2, time_left):
    
    #change activities into hotkeys
    zeros = [0] * 4
    activity1_list = zeros
    activity2_list = zeros
    activity1_list[activity1 -1] = 1
    activity2_list[activity2 -1] = 1
    
    time_left = [time_left]
    
    # Combine Data
    data = activity1_list + activity2_list + time_left
    
    return np.array([data, data])  # putting data because for now the model only accepts a list with more that one row of features


# Converts minutees to hours
def to_minutes(hr):
    return hr*60

# %%
# we Are assuming songs last for 3 minutes to know how many songs we need in our playlist

#calculate amount of hours a schedule lasts for
total_time = 0
schedule = schedule1
for block in schedule:
    duration = block["duration"]
    total_time += duration
total_time *= 60  # conversion into minutes
    
print(f"----- Total Time Scheduled: {total_time} minutes")

song_lib = {1:[BeastMode], 2:Studying, 3:BeachSongs, 4:Relaxing}

first_activity = predicted_category[0]
print(f"----- first category: {first_activity}")

# Shuffle first category
random.shuffle(song_lib[first_activity])
first_song = song_lib[first_activity][0]

def print_song(song, activity=None):
    name = first_song["name"]
    artist = first_song["artist"]
    print(f"----- First song in playlist: Name: {name}, Artist: {artist}, activity: {activity}")

print_song(first_song, first_activity)

playlist = [first_song]

# Make the entire playlist
step_size = 3  # 3 minutes
activity_time = to_minutes(schedule[0]["duration"])  # Time of first activity
print(f"----- Time for first activity: {activity_time} minutes")

time_passed = 0
curr_point = 0
present_activity = first_activity
next_activty = schedule[1]["activity"]
num_activities = len(schedule)
time_in_activity = 0
percent_time_left = 0
energy_list = []

for i in range(0,total_time, step_size):
    
    # Check to see where you are at in schedule
    if time_in_activity > to_minutes(schedule[curr_point]["duration"]):
        curr_point += 1
        curr_activity = (schedule[curr_point]["activity"])
        time_in_activity = 0
        
    # Picking next activity Check to see if there is a transition
    if time_in_activity + step_size > to_minutes(schedule[curr_point]["duration"]):
        if curr_point == (num_activities - 1): ## if there is no next activity pretend the next activity is relaxing:
            next_activity = 4  # Relaxing
        else:
            next_activity = (schedule[curr_point + 1]["activity"])
        
    else:
        next_activity = curr_activity
     
     
    # Predict Energy Change
    percent_time_left = 1 - ((time_in_activity/to_minutes(schedule[curr_point]["duration"])))
    schedule_features = time_left_feat(curr_activity, next_activity, percent_time_left)
    predictions = energy_changer_NN.predict(schedule_features)
    energy_change = np.argmax(predictions[0])  #predictions is  a list with 2 predictions. Both predictions are the same
                                                #Look in time_left_feat to know why
        
#     print(f"curr activity {curr_activity} next activity {next_activity}, time left {percent_time_left}")

    
    # Prepare Data for RNN to make prediction
    if energy_change == 1:  # energy boost
        energy_list.append(1)
        print("..Boost ^")
        
        # First Shuffle Data
        random.shuffle(song_lib[next_activity])
        
        # Loop through the next activity song lib to find more apropriate song
        song_chosen = 0
        for song in song_lib[next_activity]:
            song_features_x = song_features(song,playlist[-1])  # song in question and last song added to playlist
#             print(song_features_x)
            predictions = rnn_boost.predict(song_features_x)
            good_change = np.argmax(predictions[0])
            if good_change == 1:
                song_chosen = 1
                playlist.append(song)
#                 print(song)
                break
                
        # If appropriate song is not found. pick random song in next activity
        if song_chosen == 0:
            print('Random Song Selected')
            song_num_list = list(range(len(song_lib[next_activity])))
            random.shuffle(song_num_list)
            choice = song_num_list[0]
            song = song_lib[next_activity][choice]
            playlist.append(song)

    elif energy_change == 0: # energy drop
        energy_list.append(0)
        print("..Drop v")
        
        # First Shuffle Data
        random.shuffle(song_lib[next_activity])
        
        # Loop through the next activity song lib to find more apropriate song
        song_chosen = 0
        for song in song_lib[next_activity]:
            song_features_x = song_features(song,playlist[-1])  # song in question and last song added to playlist
#             print(song_features_x)
            predictions = rnn_drop.predict(song_features_x)
            good_change = np.argmax(predictions[0])
            if good_change == 1:
                song_chosen = 1
                playlist.append(song)
#                 print(song)
                break
                
        # If appropriate song is not found. pick random song in next activity
        if song_chosen == 0:
            print('Random Song Selected')
            song_num_list = list(range(len(song_lib[next_activity])))
            random.shuffle(song_num_list)
            choice = song_num_list[0]
            song = song_lib[next_activity][choice]
            playlist.append(song)
        
    
    time_in_activity += step_size
    
print("----- Playlist Created :) -----")
# Out:
# ----- Total Time Scheduled: 300 minutes
# ----- first category: 2
# ----- First song in playlist: Name: Drifter, Artist: C4C, activity: 2
# ----- Time for first activity: 120 minutes
# curr activity 3 next activity 3, time left 1.0
# ..Drop v
# curr activity 3 next activity 3, time left 0.975
# ..Drop v
# curr activity 3 next activity 3, time left 0.95
# ..Drop v
# curr activity 3 next activity 3, time left 0.925
# ..Drop v
# curr activity 3 next activity 3, time left 0.9
# ..Drop v
# curr activity 3 next activity 3, time left 0.875
# ..Drop v
# curr activity 3 next activity 3, time left 0.85
# ..Boost ^
# curr activity 3 next activity 3, time left 0.825
# ..Boost ^
# curr activity 3 next activity 3, time left 0.8
# ..Boost ^
# curr activity 3 next activity 3, time left 0.775
# ..Boost ^
# curr activity 3 next activity 3, time left 0.75
# ..Boost ^
# curr activity 3 next activity 3, time left 0.725
# ..Boost ^
# curr activity 3 next activity 3, time left 0.7
# ..Boost ^
# curr activity 3 next activity 3, time left 0.675
# ..Boost ^
# curr activity 3 next activity 3, time left 0.65
# ..Boost ^
# curr activity 3 next activity 3, time left 0.625
# ..Boost ^
# curr activity 3 next activity 3, time left 0.6
# ..Boost ^
# curr activity 3 next activity 3, time left 0.575
# ..Boost ^
# curr activity 3 next activity 3, time left 0.55
# ..Boost ^
# curr activity 3 next activity 3, time left 0.525
# ..Boost ^
# curr activity 3 next activity 3, time left 0.5
# ..Boost ^
# curr activity 3 next activity 3, time left 0.475
# ..Drop v
# curr activity 3 next activity 3, time left 0.44999999999999996
# ..Drop v
# curr activity 3 next activity 3, time left 0.42500000000000004
# ..Drop v
# curr activity 3 next activity 3, time left 0.4
# ..Drop v
# curr activity 3 next activity 3, time left 0.375
# ..Boost ^
# curr activity 3 next activity 3, time left 0.35
# ..Boost ^
# curr activity 3 next activity 3, time left 0.32499999999999996
# ..Boost ^
# curr activity 3 next activity 3, time left 0.30000000000000004
# ..Boost ^
# curr activity 3 next activity 3, time left 0.275
# ..Boost ^
# curr activity 3 next activity 3, time left 0.25
# ..Boost ^
# curr activity 3 next activity 3, time left 0.22499999999999998
# ..Boost ^
# curr activity 3 next activity 3, time left 0.19999999999999996
# ..Boost ^
# curr activity 3 next activity 3, time left 0.17500000000000004
# ..Boost ^
# curr activity 3 next activity 3, time left 0.15000000000000002
# ..Boost ^
# curr activity 3 next activity 3, time left 0.125
# ..Boost ^
# curr activity 3 next activity 3, time left 0.09999999999999998
# ..Boost ^
# curr activity 3 next activity 3, time left 0.07499999999999996
# ..Boost ^
# curr activity 3 next activity 3, time left 0.050000000000000044
# ..Boost ^
# curr activity 3 next activity 3, time left 0.025000000000000022
# ..Boost ^
# curr activity 3 next activity 2, time left 0.0
# ..Boost ^
# curr activity 2 next activity 2, time left 1.0
# ..Boost ^
# curr activity 2 next activity 2, time left 0.95
# ..Drop v
# curr activity 2 next activity 2, time left 0.9
# ..Drop v
# curr activity 2 next activity 2, time left 0.85
# ..Drop v
# curr activity 2 next activity 2, time left 0.8
# ..Drop v
# curr activity 2 next activity 2, time left 0.75
# ..Drop v
# curr activity 2 next activity 2, time left 0.7
# ..Drop v
# curr activity 2 next activity 2, time left 0.65
# ..Boost ^
# curr activity 2 next activity 2, time left 0.6
# ..Boost ^
# curr activity 2 next activity 2, time left 0.55
# ..Boost ^
# curr activity 2 next activity 2, time left 0.5
# ..Boost ^
# curr activity 2 next activity 2, time left 0.44999999999999996
# ..Boost ^
# curr activity 2 next activity 2, time left 0.4
# ..Boost ^
# curr activity 2 next activity 2, time left 0.35
# ..Boost ^
# curr activity 2 next activity 2, time left 0.30000000000000004
# ..Boost ^
# curr activity 2 next activity 2, time left 0.25
# ..Boost ^
# curr activity 2 next activity 2, time left 0.19999999999999996
# ..Boost ^
# curr activity 2 next activity 2, time left 0.15000000000000002
# ..Boost ^
# curr activity 2 next activity 2, time left 0.09999999999999998
# ..Boost ^
# curr activity 2 next activity 2, time left 0.050000000000000044
# ..Boost ^
# curr activity 2 next activity 3, time left 0.0
# ..Boost ^
# curr activity 3 next activity 3, time left 1.0
# ..Drop v
# curr activity 3 next activity 3, time left 0.975
# ..Drop v
# curr activity 3 next activity 3, time left 0.95
# ..Drop v
# curr activity 3 next activity 3, time left 0.925
# ..Drop v
# curr activity 3 next activity 3, time left 0.9
# ..Drop v
# curr activity 3 next activity 3, time left 0.875
# ..Drop v
# curr activity 3 next activity 3, time left 0.85
# ..Boost ^
# curr activity 3 next activity 3, time left 0.825
# ..Boost ^
# curr activity 3 next activity 3, time left 0.8
# ..Boost ^
# curr activity 3 next activity 3, time left 0.775
# ..Boost ^
# curr activity 3 next activity 3, time left 0.75
# ..Boost ^
# curr activity 3 next activity 3, time left 0.725
# ..Boost ^
# curr activity 3 next activity 3, time left 0.7
# ..Boost ^
# curr activity 3 next activity 3, time left 0.675
# ..Boost ^
# curr activity 3 next activity 3, time left 0.65
# ..Boost ^
# curr activity 3 next activity 3, time left 0.625
# ..Boost ^
# curr activity 3 next activity 3, time left 0.6
# ..Boost ^
# curr activity 3 next activity 3, time left 0.575
# ..Boost ^
# curr activity 3 next activity 3, time left 0.55
# ..Boost ^
# curr activity 3 next activity 3, time left 0.525
# ..Boost ^
# curr activity 3 next activity 3, time left 0.5
# ..Boost ^
# curr activity 3 next activity 3, time left 0.475
# ..Drop v
# curr activity 3 next activity 3, time left 0.44999999999999996
# ..Drop v
# curr activity 3 next activity 3, time left 0.42500000000000004
# ..Drop v
# curr activity 3 next activity 3, time left 0.4
# ..Drop v
# curr activity 3 next activity 3, time left 0.375
# ..Boost ^
# curr activity 3 next activity 3, time left 0.35
# ..Boost ^
# curr activity 3 next activity 3, time left 0.32499999999999996
# ..Boost ^
# curr activity 3 next activity 3, time left 0.30000000000000004
# ..Boost ^
# curr activity 3 next activity 3, time left 0.275
# ..Boost ^
# curr activity 3 next activity 3, time left 0.25
# ..Boost ^
# curr activity 3 next activity 3, time left 0.22499999999999998
# ..Boost ^
# curr activity 3 next activity 3, time left 0.19999999999999996
# ..Boost ^
# curr activity 3 next activity 3, time left 0.17500000000000004
# ..Boost ^
# curr activity 3 next activity 3, time left 0.15000000000000002
# ..Boost ^
# curr activity 3 next activity 3, time left 0.125
# ..Boost ^
# curr activity 3 next activity 3, time left 0.09999999999999998
# ..Boost ^
# curr activity 3 next activity 3, time left 0.07499999999999996
# ..Boost ^
# ----- Playlist Created :) -----

# %%
#### Plotting Data
# Out:
# array([[9, 8],
#        [9, 8]])
